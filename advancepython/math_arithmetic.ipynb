# %%
import pandas as pd

# %%
df=pd.DataFrame(
    [
        [10,20,30],
        [2,4,6],
        [5,7,8]
    ]
)
df
# Out:
#     0   1   2
# 0  10  20  30
# 1   2   4   6
# 2   5   7   8

# %% [markdown]
# # add

# %%
df+1
# Out:
#     0   1   2
# 0  11  21  31
# 1   3   5   7
# 2   6   8   9

# %%
df.add(1)
# Out:
#     0   1   2
# 0  11  21  31
# 1   3   5   7
# 2   6   8   9

# %% [markdown]
# #Sub

# %%
df-1
# Out:
#    0   1   2
# 0  9  19  29
# 1  1   3   5
# 2  4   6   7

# %%
df.sub(1)
# Out:
#    0   1   2
# 0  9  19  29
# 1  1   3   5
# 2  4   6   7

# %%
df.subtract(1)
# Out:
#    0   1   2
# 0  9  19  29
# 1  1   3   5
# 2  4   6   7

# %%
# mul

# %%
df*5
# Out:
#     0    1    2
# 0  50  100  150
# 1  10   20   30
# 2  25   35   40

# %%
df.mul(5)
# Out:
#     0    1    2
# 0  50  100  150
# 1  10   20   30
# 2  25   35   40

# %%
df.multiply(5)
# Out:
#     0    1    2
# 0  50  100  150
# 1  10   20   30
# 2  25   35   40

# %% [markdown]
# # division

# %%
df/2
# Out:
#      0     1     2
# 0  5.0  10.0  15.0
# 1  1.0   2.0   3.0
# 2  2.5   3.5   4.0

# %%
df.div(2)
# Out:
#      0     1     2
# 0  5.0  10.0  15.0
# 1  1.0   2.0   3.0
# 2  2.5   3.5   4.0

# %%
df.divide(2)
# Out:
#      0     1     2
# 0  5.0  10.0  15.0
# 1  1.0   2.0   3.0
# 2  2.5   3.5   4.0

# %%
#mod

# %%
df%3
# Out:
#    0  1  2
# 0  1  2  0
# 1  2  1  0
# 2  2  1  2

# %%
df.mod(3)
# Out:
#    0  1  2
# 0  1  2  0
# 1  2  1  0
# 2  2  1  2

# %% [markdown]
# # Floor Division

# %%
df//2
# Out:
#    0   1   2
# 0  5  10  15
# 1  1   2   3
# 2  2   3   4

# %%
df.floordiv(2)
# Out:
#    0   1   2
# 0  5  10  15
# 1  1   2   3
# 2  2   3   4

# %%
df
# Out:
#     0   1   2
# 0  10  20  30
# 1   2   4   6
# 2   5   7   8

# %%
df.columns=['A','B','C']
df
# Out:
#     A   B   C
# 0  10  20  30
# 1   2   4   6
# 2   5   7   8

# %%
df['A']
# Out:
# 0    10
# 1     2
# 2     5
# Name: A, dtype: int64

# %%
df['A']+2
# Out:
# 0    12
# 1     4
# 2     7
# Name: A, dtype: int64

# %%
df['A']+ df['B']
# Out:
# 0    30
# 1     6
# 2    12
# dtype: int64

# %%
df['D']=df['A']+ df['B']

# %%
df
# Out:
#     A   B   C   D
# 0  10  20  30  30
# 1   2   4   6   6
# 2   5   7   8  12

# %%
# matrix Multiplication

# %%
a=pd.DataFrame(
    [
        [1,2],
        [3,4]
    ]
)
a
# Out:
#    0  1
# 0  1  2
# 1  3  4

# %%
b=pd.DataFrame(
    [
        [5,6],
        [7,8]
    ]
)
b
# Out:
#    0  1
# 0  5  6
# 1  7  8

# %%
a.dot(b)
# Out:
#     0   1
# 0  19  22
# 1  43  50

# %%
df=pd.DataFrame(
    [
        [10,200],
        [2,300],
        [5,500]
    ]
)
df.columns=['qty','price']
df
# Out:
#    qty  price
# 0   10    200
# 1    2    300
# 2    5    500

# %%
df['Total']=df['qty']*df['price']

# %%
df
# Out:
#    qty  price  Total
# 0   10    200   2000
# 1    2    300    600
# 2    5    500   2500

# %%
df.eval("tot=qty*price",inplace=True)

# %%
df
# Out:
#    qty  price  Total   tot
# 0   10    200   2000  2000
# 1    2    300    600   600
# 2    5    500   2500  2500
