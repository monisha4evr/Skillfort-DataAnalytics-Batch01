# %%
import numpy as np

# %%
np.random.rand()
# Out:
# 0.7111676614388087

# %%
np.random.rand(3)
# Out:
# array([0.12914918, 0.32364038, 0.00386347])

# %%
np.random.rand(2,3)
# Out:
# array([[0.84550095, 0.15513896, 0.03605839],
#        [0.74791073, 0.11421565, 0.27588262]])

# %%
np.random.randint(1,10)
# Out:
# 3

# %%
arr=np.array(["Apple","orange","Banana"])
np.random.choice(arr)
# Out:
# np.str_('Apple')

# %%
np.random.seed(21)
np.random.rand(3)
# Out:
# array([0.04872488, 0.28910966, 0.72096635])

# %%
rng=np.random.default_rng()
rng.random()
# Out:
# 0.18801312320142316

# %%
rng.random()*10
# Out:
# 2.8233525877024404

# %%
rng.integers((1,6))
# Out:
# array([0, 5])

# %%
rng.integers(1,6,size=5)
# Out:
# array([2, 4, 2, 2, 4])

# %%
arr=np.array(["Apple","orange","Banana"])
rng.choice(arr,size=5,replace=True)
# Out:
# array(['orange', 'Banana', 'Banana', 'Banana', 'Banana'], dtype='<U6')

# %%
arr=np.array(["Apple","orange","Banana"])
rng.choice(arr,size=5,replace=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 2
#       1 arr=np.array(["Apple","orange","Banana"])
# ----> 2 rng.choice(arr,size=5,replace=False)
#
# File numpy/random/_generator.pyx:925, in numpy.random._generator.Generator.choice()
# --> 925 'Could not get source, probably due dynamically evaluated source code.'
#
# ValueError: Cannot take a larger sample than population when replace is False

# %%
arr=np.array(["Apple","orange","Banana"])
rng.choice(arr,size=2,replace=False)
# Out:
# array(['Apple', 'orange'], dtype='<U6')
