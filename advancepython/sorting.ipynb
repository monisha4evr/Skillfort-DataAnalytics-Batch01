# %%
import pandas as pd

# %%
df_sort=pd.read_csv('car_data_500.csv').head()
df_sort
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin
# 0     76    Japan
# 1     73       US
# 2     80    India
# 3     77  Germany
# 4     74       US

# %%
df_sort.sort_index(axis=1)
# Out:
#    Accelarate  Cylinder  Displacement  Horsepower   MPO  Model      car  \
# 0        15.5       6.0          1823         247  20.7     76     Ford
# 1        15.9       4.0          1793         186  17.4     73   Jaguar
# 2         8.3       8.0          1943         265  21.3     80     Audi
# 3         9.9       6.0          4498         196  11.5     77  Hyundai
# 4         7.2       6.0          2968         140  18.0     74     Tata
#
#     origin  weight
# 0    Japan    3374
# 1       US    2196
# 2    India    3527
# 3  Germany    3317
# 4       US    2706

# %%
df_sort.sort_values(by="car")
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin
# 2     80    India
# 0     76    Japan
# 3     77  Germany
# 1     73       US
# 4     74       US

# %%
df_sort.sort_values(by=["car",'origin'])
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin
# 2     80    India
# 0     76    Japan
# 3     77  Germany
# 1     73       US
# 4     74       US

# %%
df_sort
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin
# 0     76    Japan
# 1     73       US
# 2     80    India
# 3     77  Germany
# 4     74       US

# %%
df_sort.sort_values(by="car", ascending=False)
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 4     Tata  18.0       6.0          2968         140    2706         7.2
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 2     Audi  21.3       8.0          1943         265    3527         8.3
#
#    Model   origin
# 4     74       US
# 1     73       US
# 3     77  Germany
# 0     76    Japan
# 2     80    India

# %%
df_sort.sort_values(by="car", ascending=False,inplace=True)

# %%
df_sort
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 4     Tata  18.0       6.0          2968         140    2706         7.2
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 2     Audi  21.3       8.0          1943         265    3527         8.3
#
#    Model   origin
# 4     74       US
# 1     73       US
# 3     77  Germany
# 0     76    Japan
# 2     80    India
