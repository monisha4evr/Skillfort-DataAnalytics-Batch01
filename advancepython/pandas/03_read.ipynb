# %%
import pandas as pd

# %%
import openpyxl as op
op.__version__
# Out:
# '3.1.5'

# %%
df=pd.read_clipboard()
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3

# %%
df=pd.read_csv('../../../data_colon.csv',delimiter=':')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df=pd.read_excel('../../../Project-Management-Sample-Data.xlsx',engine='openpyxl',skiprows=5,usecols="b:h")
df  # To solve this Error commdand : pip install openpyxl
# Out:
#     Project Name                Task Name Assigned to Start Date  \
# 0      Marketing          Market Research       Alice 2024-01-01
# 1      Marketing         Content Creation         Bob 2024-01-14
# 2      Marketing    Social Media Planning     Charlie 2024-01-28
# 3      Marketing        Campaign Analysis       Daisy 2024-02-18
# 4    Product Dev    Prototype Development       Ethan 2024-01-02
# 5    Product Dev        Quality Assurance       Fiona 2024-01-20
# 6    Product Dev    User Interface Design     Gabriel 2024-02-04
# 7   Customer Svc      Service Improvement      Hannah 2024-02-01
# 8   Customer Svc        Ticket Resolution         Ian 2024-02-24
# 9   Customer Svc        Customer Feedback       Julia 2024-03-21
# 10     Financial          Budget Analysis       Kevin 2024-02-02
# 11     Financial      Financial Reporting        Mark 2024-02-13
# 12     Financial      Investment Planning        Mark 2024-03-19
# ...
