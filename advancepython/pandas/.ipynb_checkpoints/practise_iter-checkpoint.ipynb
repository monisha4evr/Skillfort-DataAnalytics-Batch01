# %%
import pandas as pd

# %%
df_copy=pd.read_csv("../../../car_data_500.csv").head()
df_copy
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin
# 0     76    Japan
# 1     73       US
# 2     80    India
# 3     77  Germany
# 4     74       US

# %% [markdown]
# # Series

# %%
list(df_copy['Cylinder'].items())
# Out:
# [(0, 6.0), (1, 4.0), (2, 8.0), (3, 6.0), (4, 6.0)]

# %%
for i,v in df_copy['Cylinder'].items():
    print(f"i {i}- value:{v}")
# Out:
# i 0- value:6.0
# i 1- value:4.0
# i 2- value:8.0
# i 3- value:6.0
# i 4- value:6.0

# %%
cnt=0
for i,v in df_copy['Cylinder'].items():
    if v==6.0:
        cnt+=1
        print(f"index {i}- value:{v}")
print("Total occurance: ",cnt)
# Out:
# index 0- value:6.0
# index 3- value:6.0
# index 4- value:6.0
# Total occurance:  3

# %% [markdown]
# # DataFrame

# %%
for item in df_copy.items():
    print(item)
# Out:
# ('car', 0       Ford
# 1     Jaguar
# 2       Audi
# 3    Hyundai
# 4       Tata
# Name: car, dtype: str)
# ('MPO', 0    20.7
# 1    17.4
# 2    21.3
# 3    11.5
# 4    18.0
# Name: MPO, dtype: float64)
# ('Cylinder', 0    6.0
# 1    4.0
# 2    8.0
# 3    6.0
# 4    6.0
# Name: Cylinder, dtype: float64)
# ('Displacement', 0    1823
# 1    1793
# 2    1943
# 3    4498
# 4    2968
# Name: Displacement, dtype: int64)
# ('Horsepower', 0    247
# 1    186
# 2    265
# 3    196
# 4    140
# Name: Horsepower, dtype: int64)
# ('weight', 0    3374
# 1    2196
# 2    3527
# 3    3317
# 4    2706
# Name: weight, dtype: int64)
# ('Accelarate', 0    15.5
# 1    15.9
# 2     8.3
# 3     9.9
# 4     7.2
# Name: Accelarate, dtype: float64)
# ('Model', 0    76
# 1    73
# 2    80
# 3    77
# 4    74
# Name: Model, dtype: int64)
# ('origin', 0      Japan
# 1         US
# 2      India
# 3    Germany
# 4         US
# Name: origin, dtype: str)

# %%
for item in df_copy.items():
    print(item)
    break
# Out:
# ('car', 0       Ford
# 1     Jaguar
# 2       Audi
# 3    Hyundai
# 4       Tata
# Name: car, dtype: str)

# %%
for item in df_copy.items():
    print(item[1]) # 0 index
# Out:
# 0       Ford
# 1     Jaguar
# 2       Audi
# 3    Hyundai
# 4       Tata
# Name: car, dtype: str
# 0    20.7
# 1    17.4
# 2    21.3
# 3    11.5
# 4    18.0
# Name: MPO, dtype: float64
# 0    6.0
# 1    4.0
# 2    8.0
# 3    6.0
# 4    6.0
# Name: Cylinder, dtype: float64
# 0    1823
# 1    1793
# 2    1943
# 3    4498
# 4    2968
# Name: Displacement, dtype: int64
# 0    247
# 1    186
# 2    265
# 3    196
# 4    140
# Name: Horsepower, dtype: int64
# 0    3374
# 1    2196
# 2    3527
# 3    3317
# 4    2706
# Name: weight, dtype: int64
# 0    15.5
# 1    15.9
# 2     8.3
# 3     9.9
# 4     7.2
# Name: Accelarate, dtype: float64
# 0    76
# 1    73
# 2    80
# 3    77
# 4    74
# Name: Model, dtype: int64
# 0      Japan
# 1         US
# 2      India
# 3    Germany
# 4         US
# Name: origin, dtype: str

# %%
df_copy.items()
# Out:
# <generator object DataFrame.items at 0x0000025D55ED1F40>

# %%
list(df_copy.items())
# Out:
# [('car',
#   0       Ford
#   1     Jaguar
#   2       Audi
#   3    Hyundai
#   4       Tata
#   Name: car, dtype: str),
#  ('MPO',
#   0    20.7
#   1    17.4
#   2    21.3
#   3    11.5
#   4    18.0
#   Name: MPO, dtype: float64),
#  ('Cylinder',
#   0    6.0
#   1    4.0
#   2    8.0
#   3    6.0
#   4    6.0
#   Name: Cylinder, dtype: float64),
#  ('Displacement',
#   0    1823
#   1    1793
#   2    1943
#   3    4498
#   4    2968
#   Name: Displacement, dtype: int64),
#  ('Horsepower',
#   0    247
#   1    186
#   2    265
#   3    196
#   4    140
#   Name: Horsepower, dtype: int64),
#  ('weight',
#   0    3374
#   1    2196
#   2    3527
#   3    3317
#   4    2706
#   Name: weight, dtype: int64),
#  ('Accelarate',
#   0    15.5
#   1    15.9
#   2     8.3
#   3     9.9
#   4     7.2
#   Name: Accelarate, dtype: float64),
#  ('Model',
#   0    76
#   1    73
#   2    80
#   3    77
#   4    74
#   Name: Model, dtype: int64),
#  ('origin',
#   0      Japan
# ...

# %%
list(df_copy.iterrows())
# Out:
# [(0,
#   car              Ford
#   MPO              20.7
#   Cylinder          6.0
#   Displacement     1823
#   Horsepower        247
#   weight           3374
#   Accelarate       15.5
#   Model              76
#   origin          Japan
#   Name: 0, dtype: object),
#  (1,
#   car             Jaguar
#   MPO               17.4
#   Cylinder           4.0
#   Displacement      1793
#   Horsepower         186
#   weight            2196
#   Accelarate        15.9
#   Model               73
#   origin              US
#   Name: 1, dtype: object),
#  (2,
#   car              Audi
#   MPO              21.3
#   Cylinder          8.0
#   Displacement     1943
#   Horsepower        265
#   weight           3527
#   Accelarate        8.3
#   Model              80
#   origin          India
#   Name: 2, dtype: object),
#  (3,
#   car             Hyundai
#   MPO                11.5
#   Cylinder            6.0
#   Displacement       4498
#   Horsepower          196
#   weight             3317
# ...

# %%
df_copy.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x0000025D55F0D580>

# %%
df_copy.itertuples()

# %%
list(df_copy.iterrows())
# Out:
# [(0,
#   car              Ford
#   MPO              20.7
#   Cylinder          6.0
#   Displacement     1823
#   Horsepower        247
#   weight           3374
#   Accelarate       15.5
#   Model              76
#   origin          Japan
#   Name: 0, dtype: object),
#  (1,
#   car             Jaguar
#   MPO               17.4
#   Cylinder           4.0
#   Displacement      1793
#   Horsepower         186
#   weight            2196
#   Accelarate        15.9
#   Model               73
#   origin              US
#   Name: 1, dtype: object),
#  (2,
#   car              Audi
#   MPO              21.3
#   Cylinder          8.0
#   Displacement     1943
#   Horsepower        265
#   weight           3527
#   Accelarate        8.3
#   Model              80
#   origin          India
#   Name: 2, dtype: object),
#  (3,
#   car             Hyundai
#   MPO                11.5
#   Cylinder            6.0
#   Displacement       4498
#   Horsepower          196
#   weight             3317
# ...

# %%
list(df_copy.itertuples())
# Out:
# [Pandas(Index=0, car='Ford', MPO=20.7, Cylinder=6.0, Displacement=1823, Horsepower=247, weight=3374, Accelarate=15.5, Model=76, origin='Japan'),
#  Pandas(Index=1, car='Jaguar', MPO=17.4, Cylinder=4.0, Displacement=1793, Horsepower=186, weight=2196, Accelarate=15.9, Model=73, origin='US'),
#  Pandas(Index=2, car='Audi', MPO=21.3, Cylinder=8.0, Displacement=1943, Horsepower=265, weight=3527, Accelarate=8.3, Model=80, origin='India'),
#  Pandas(Index=3, car='Hyundai', MPO=11.5, Cylinder=6.0, Displacement=4498, Horsepower=196, weight=3317, Accelarate=9.9, Model=77, origin='Germany'),
#  Pandas(Index=4, car='Tata', MPO=18.0, Cylinder=6.0, Displacement=2968, Horsepower=140, weight=2706, Accelarate=7.2, Model=74, origin='US')]
