# %%
import pandas as pd

# %%
df=pd.read_csv("../../../car_data_500.csv").head(6) 
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
# 5      Kia  15.7       6.0          2659         155    3156        10.2
#
#    Model   origin
# 0     76    Japan
# 1     73       US
# 2     80    India
# 3     77  Germany
# 4     74       US
# 5     76       US

# %%
# series

# %%
df['car']
# Out:
# 0       Ford
# 1     Jaguar
# 2       Audi
# 3    Hyundai
# 4       Tata
# 5        Kia
# Name: car, dtype: str

# %%
df['car'].items()

# %%
list(df['car'].items())
# Out:
# [(0, 'Ford'),
#  (1, 'Jaguar'),
#  (2, 'Audi'),
#  (3, 'Hyundai'),
#  (4, 'Tata'),
#  (5, 'Kia')]

# %%
for i,v in df['car'].items():
    print(i,v)
# Out:
# 0 Ford
# 1 Jaguar
# 2 Audi
# 3 Hyundai
# 4 Tata
# 5 Kia

# %%
for i,v in df['car'].items():
    if v=="Audi":
      print(i,v)
# Out:
# 2 Audi

# %%
df.items()
# Out:
# <generator object DataFrame.items at 0x000001B5820F2A40>

# %%
list(df.items())
# Out:
# [('car',
#   0       Ford
#   1     Jaguar
#   2       Audi
#   3    Hyundai
#   4       Tata
#   5        Kia
#   Name: car, dtype: str),
#  ('MPO',
#   0    20.7
#   1    17.4
#   2    21.3
#   3    11.5
#   4    18.0
#   5    15.7
#   Name: MPO, dtype: float64),
#  ('Cylinder',
#   0    6.0
#   1    4.0
#   2    8.0
#   3    6.0
#   4    6.0
#   5    6.0
#   Name: Cylinder, dtype: float64),
#  ('Displacement',
#   0    1823
#   1    1793
#   2    1943
#   3    4498
#   4    2968
#   5    2659
#   Name: Displacement, dtype: int64),
#  ('Horsepower',
#   0    247
#   1    186
#   2    265
#   3    196
#   4    140
#   5    155
#   Name: Horsepower, dtype: int64),
#  ('weight',
#   0    3374
#   1    2196
#   2    3527
#   3    3317
#   4    2706
#   5    3156
#   Name: weight, dtype: int64),
#  ('Accelarate',
#   0    15.5
#   1    15.9
#   2     8.3
#   3     9.9
#   4     7.2
#   5    10.2
#   Name: Accelarate, dtype: float64),
#  ('Model',
#   0    76
#   1    73
#   2    80
# ...

# %%
for item in df.items():
    print(item)
    break
# Out:
# ('car', 0       Ford
# 1     Jaguar
# 2       Audi
# 3    Hyundai
# 4       Tata
# 5        Kia
# Name: car, dtype: str)

# %%
df.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x000001B58253D470>

# %%
for i in df.iterrows():
    print(i)
# Out:
# (0, car              Ford
# MPO              20.7
# Cylinder          6.0
# Displacement     1823
# Horsepower        247
# weight           3374
# Accelarate       15.5
# Model              76
# origin          Japan
# Name: 0, dtype: object)
# (1, car             Jaguar
# MPO               17.4
# Cylinder           4.0
# Displacement      1793
# Horsepower         186
# weight            2196
# Accelarate        15.9
# Model               73
# origin              US
# Name: 1, dtype: object)
# (2, car              Audi
# MPO              21.3
# Cylinder          8.0
# Displacement     1943
# Horsepower        265
# weight           3527
# Accelarate        8.3
# Model              80
# origin          India
# Name: 2, dtype: object)
# (3, car             Hyundai
# MPO                11.5
# Cylinder            6.0
# Displacement       4498
# Horsepower          196
# weight             3317
# Accelarate          9.9
# Model                77
# origin          Germany
# ...

# %%
df.itertuples()

# %%
for i in df.itertuples():
    print(i)
# Out:
# Pandas(Index=0, car='Ford', MPO=20.7, Cylinder=6.0, Displacement=1823, Horsepower=247, weight=3374, Accelarate=15.5, Model=76, origin='Japan')
# Pandas(Index=1, car='Jaguar', MPO=17.4, Cylinder=4.0, Displacement=1793, Horsepower=186, weight=2196, Accelarate=15.9, Model=73, origin='US')
# Pandas(Index=2, car='Audi', MPO=21.3, Cylinder=8.0, Displacement=1943, Horsepower=265, weight=3527, Accelarate=8.3, Model=80, origin='India')
# Pandas(Index=3, car='Hyundai', MPO=11.5, Cylinder=6.0, Displacement=4498, Horsepower=196, weight=3317, Accelarate=9.9, Model=77, origin='Germany')
# Pandas(Index=4, car='Tata', MPO=18.0, Cylinder=6.0, Displacement=2968, Horsepower=140, weight=2706, Accelarate=7.2, Model=74, origin='US')
# Pandas(Index=5, car='Kia', MPO=15.7, Cylinder=6.0, Displacement=2659, Horsepower=155, weight=3156, Accelarate=10.2, Model=76, origin='US')
