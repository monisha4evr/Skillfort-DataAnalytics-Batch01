# %%
import pandas as pd

# %%
df=pd.read_csv('../../../pandas_50_records.csv')
df=df.head()

# %% [raw]
# Check Null Value
# 1. df.isna() # true if null value Present
# 2. df.isna().sum() #Based on Columnwise
# 3. df.isnull()
# 4. df.isnull().sum()
# 5. df.loc[df['Horsepower'].isna()]

# %%
df.isna()
# Out:
#       ID   Name    Age  Course  Marks   City
# 0  False  False  False   False  False  False
# 1  False  False  False   False  False  False
# 2  False  False  False   False  False  False
# 3  False  False   True   False  False  False
# 4  False  False  False   False  False  False

# %%
df.isna().sum()
# Out:
# ID        0
# Name      0
# Age       1
# Course    0
# Marks     0
# City      0
# dtype: int64

# %%
df.isnull()
# Out:
#       ID   Name    Age  Course  Marks   City
# 0  False  False  False   False  False  False
# 1  False  False  False   False  False  False
# 2  False  False  False   False  False  False
# 3  False  False   True   False  False  False
# 4  False  False  False   False  False  False

# %%
df.isnull().sum()
# Out:
# ID        0
# Name      0
# Age       1
# Course    0
# Marks     0
# City      0
# dtype: int64

# %%
df['Age'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: Age, dtype: bool

# %%
df.loc[df['Age'].isnull()]
# Out:
#    ID       Name  Age    Course  Marks     City
# 3   4  Student_4  NaN  Power BI   78.0  Chennai

# %%
df.loc[~ df['Age'].isnull()]
# Out:
#    ID       Name   Age  Course  Marks     City
# 0   1  Student_1  24.0     SQL   62.0    Salem
# 1   2  Student_2  21.0  Pandas   70.0    Salem
# 2   3  Student_3  22.0     SQL   88.0  Madurai
# 4   5  Student_5  20.0     SQL   54.0    Salem

# %% [markdown]
# - Drop Null Value row
# - df.dropna()
# - df.fillna(1000)
# - df.dropna(how="all")
# - df.dropna(how="any")
# - df.dropna(subset=["Age"])
# - df.dropna(thresh=6)

# %%
df
# Out:
#    ID       Name   Age    Course  Marks     City
# 0   1  Student_1  24.0       SQL   62.0    Salem
# 1   2  Student_2  21.0    Pandas   70.0    Salem
# 2   3  Student_3  22.0       SQL   88.0  Madurai
# 3   4  Student_4   NaN  Power BI   78.0  Chennai
# 4   5  Student_5  20.0       SQL   54.0    Salem

# %%
df.shape
# Out:
# (5, 6)

# %%
df.dropna()
# Out:
#    ID       Name   Age  Course  Marks     City
# 0   1  Student_1  24.0     SQL   62.0    Salem
# 1   2  Student_2  21.0  Pandas   70.0    Salem
# 2   3  Student_3  22.0     SQL   88.0  Madurai
# 4   5  Student_5  20.0     SQL   54.0    Salem

# %%
df.dropna().shape
# Out:
# (4, 6)

# %%
df['City'].dropna()
# Out:
# 0      Salem
# 1      Salem
# 2    Madurai
# 3    Chennai
# 4      Salem
# Name: City, dtype: str

# %%
df.dropna(how="all")
# Out:
#    ID       Name   Age    Course  Marks     City
# 0   1  Student_1  24.0       SQL   62.0    Salem
# 1   2  Student_2  21.0    Pandas   70.0    Salem
# 2   3  Student_3  22.0       SQL   88.0  Madurai
# 3   4  Student_4   NaN  Power BI   78.0  Chennai
# 4   5  Student_5  20.0       SQL   54.0    Salem

# %%
df.dropna(how="any")
# Out:
#    ID       Name   Age  Course  Marks     City
# 0   1  Student_1  24.0     SQL   62.0    Salem
# 1   2  Student_2  21.0  Pandas   70.0    Salem
# 2   3  Student_3  22.0     SQL   88.0  Madurai
# 4   5  Student_5  20.0     SQL   54.0    Salem

# %%
df.dropna(thresh=4)
# Out:
#    ID       Name   Age    Course  Marks     City
# 0   1  Student_1  24.0       SQL   62.0    Salem
# 1   2  Student_2  21.0    Pandas   70.0    Salem
# 2   3  Student_3  22.0       SQL   88.0  Madurai
# 3   4  Student_4   NaN  Power BI   78.0  Chennai
# 4   5  Student_5  20.0       SQL   54.0    Salem

# %%
df.dropna(thresh=6)
# Out:
#    ID       Name   Age  Course  Marks     City
# 0   1  Student_1  24.0     SQL   62.0    Salem
# 1   2  Student_2  21.0  Pandas   70.0    Salem
# 2   3  Student_3  22.0     SQL   88.0  Madurai
# 4   5  Student_5  20.0     SQL   54.0    Salem

# %%
 df.fillna(1000)
# Out:
#    ID       Name     Age    Course  Marks     City
# 0   1  Student_1    24.0       SQL   62.0    Salem
# 1   2  Student_2    21.0    Pandas   70.0    Salem
# 2   3  Student_3    22.0       SQL   88.0  Madurai
# 3   4  Student_4  1000.0  Power BI   78.0  Chennai
# 4   5  Student_5    20.0       SQL   54.0    Salem
