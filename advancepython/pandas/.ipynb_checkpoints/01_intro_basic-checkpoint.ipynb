# %% [markdown]
# # Pandas

# %% [markdown]
# - Data Analysis and Manipulation

# %% [markdown]
# - Fast
# - open Source

# %% [markdown]
# # installation
# - pip install pandas

# %%
import pandas as pd
pd.__version__
# Out:
# '3.0.5'

# %%
1. Series  - 1D 
2. DataFrame - 2D

# %% [markdown]
# # Series

# %%
a=[10,20,30,40,50]
myvar=pd.Series(a)
myvar
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
a=[10,20,30,40,50]
myvar=pd.Series(a,index=['a','b','c','d','e'])
myvar
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
a=(10,20,30,40,50)
myvar=pd.Series(a)
myvar
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
a=(10,20,30,40,50)
myvar=pd.Series(a,index=['a','b','c','d','e'])
myvar
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64
