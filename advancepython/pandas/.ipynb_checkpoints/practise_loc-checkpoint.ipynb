# %%
import pandas as pd

# %%
df=pd.read_csv("../../../car_data_500.csv").head()
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin
# 0     76    Japan
# 1     73       US
# 2     80    India
# 3     77  Germany
# 4     74       US

# %% [markdown]
# # access Cell

# %%
df.at[0,'car']
# Out:
# 'Ford'

# %%
df.at[2,'Displacement']
# Out:
# np.int64(1943)

# %%
df.at[3,'origin']
# Out:
# 'Germany'

# %%
df.iat[0,0]
# Out:
# 'Ford'

# %%
df.loc[3,'car']
# Out:
# 'Hyundai'

# %%
df.iloc[3,3]
# Out:
# np.int64(4498)

# %%
df.loc[3].at['car']
# Out:
# 'Hyundai'

# %% [markdown]
# # access Row

# %%
df.loc[0]
# Out:
# car              Ford
# MPO              20.7
# Cylinder          6.0
# Displacement     1823
# Horsepower        247
# weight           3374
# Accelarate       15.5
# Model              76
# origin          Japan
# Name: 0, dtype: object

# %%
df.loc[1:3]
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
#
#    Model   origin
# 1     73       US
# 2     80    India
# 3     77  Germany

# %%
df.loc[[1,2,4]]
# Out:
#       car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 1  Jaguar  17.4       4.0          1793         186    2196        15.9
# 2    Audi  21.3       8.0          1943         265    3527         8.3
# 4    Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model origin
# 1     73     US
# 2     80  India
# 4     74     US

# %% [markdown]
# # access column

# %%
df.loc[:,'car']
# Out:
# 0       Ford
# 1     Jaguar
# 2       Audi
# 3    Hyundai
# 4       Tata
# Name: car, dtype: str

# %%
df.loc[:,'origin']='US'

# %%
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model origin
# 0     76     US
# 1     73     US
# 2     80     US
# 3     77     US
# 4     74     US

# %%
df.loc[:,'Model']=range(0,5)
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model origin
# 0      0     US
# 1      1     US
# 2      2     US
# 3      3     US
# 4      4     US
