# %%
import pandas as pd

# %% [markdown]
# - df['origin'].unique()
# - df['origin'].value_counts()
# - Find Duplicates: df.duplicated().sum()
# - Remove: df.drop_duplicates().head()
# ## Ranking
# - df.nlargest(3,'weight')
# - df_head.nsmallest(4,'Displacement')
# ## Ranking Row
# - df_head['Rank']=df_head['Accelarate'].rank(method='first')
# - method=> min,max,dense,first
# - df_head[df_head['Rank']<=3]

# %% [markdown]
# # Statistical Analysis
# 1. df['weight'].skew()
# 2. df['weight'].kurt()
# 3. Data distributed across dataset :
# ## 50% of data Distribution
# df['weight'].quantile()
# 4. Ranking: df_head.nlargest(3,'weight')

# %% [markdown]
# # Relationship Analysis
# ## 1. Covariance - how one Variable move with Other Variable in terms of Direction(Covariance → direction)
# - height incr -> weight incr => Positive
# - height incr -> weight decr => Negative
# - df['Horsepower'].cov(df['weight'])
# ## 2. Correlation → direction + strength
# - df['Horsepower'].corr(df['weight'])*100

# %%
df=pd.read_csv('../../../car_data_500.csv').head()
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin
# 0     76    Japan
# 1     73       US
# 2     80    India
# 3     77  Germany
# 4     74       US

# %%
df['origin'].unique()
# Out:
# <StringArray>
# ['Japan', 'US', 'India', 'Germany']
# Length: 4, dtype: str

# %%
df['Cylinder'].unique()
# Out:
# array([6., 4., 8.])

# %%
df['Cylinder'].nunique()
# Out:
# 3

# %%
df['origin'].nunique()
# Out:
# 4

# %%
df.loc[df['origin'].duplicated()]
# Out:
#     car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  Model  \
# 4  Tata  18.0       6.0          2968         140    2706         7.2     74
#
#   origin
# 4     US

# %%
df['origin'].drop_duplicates()
# Out:
# 0      Japan
# 1         US
# 2      India
# 3    Germany
# Name: origin, dtype: str

# %%
df.nlargest(3,'weight')
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
#
#    Model   origin
# 2     80    India
# 0     76    Japan
# 3     77  Germany

# %%
df.nsmallest(3,'weight')
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
#
#    Model   origin
# 1     73       US
# 4     74       US
# 3     77  Germany

# %%
df['Rank']=df['Accelarate'].rank(method='first')
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin  Rank
# 0     76    Japan   4.0
# 1     73       US   5.0
# 2     80    India   2.0
# 3     77  Germany   3.0
# 4     74       US   1.0

# %%
df['Rank']=df['Cylinder'].rank(method='first')
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin  Rank
# 0     76    Japan   2.0
# 1     73       US   1.0
# 2     80    India   5.0
# 3     77  Germany   3.0
# 4     74       US   4.0

# %%
df['Rank']=df['Cylinder'].rank(method='min')
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin  Rank
# 0     76    Japan   2.0
# 1     73       US   1.0
# 2     80    India   5.0
# 3     77  Germany   2.0
# 4     74       US   2.0

# %%
df['Rank']=df['Cylinder'].rank(method='max')
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin  Rank
# 0     76    Japan   4.0
# 1     73       US   1.0
# 2     80    India   5.0
# 3     77  Germany   4.0
# 4     74       US   4.0

# %%
df['Rank']=df['Cylinder'].rank(method='dense')
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin  Rank
# 0     76    Japan   2.0
# 1     73       US   1.0
# 2     80    India   3.0
# 3     77  Germany   2.0
# 4     74       US   2.0

# %%
df['weight'].skew()
# Out:
# np.float64(-0.9671008294148353)

# %%
df['weight'].quantile()
# Out:
# np.float64(3317.0)

# %%
df['weight'].quantile(.25)
# Out:
# np.float64(2706.0)
