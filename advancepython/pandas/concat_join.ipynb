# %%
import pandas as pd

# %%
# concat join Vertical
# pd.concat([df1,df2])

# %%
df1=pd.DataFrame(
    [
        [1,5],
        [5,2]
    ]
)
df1.columns=['A','B']
df1
# Out:
#    A  B
# 0  1  5
# 1  5  2

# %%
df2=pd.DataFrame([
    [12,5],
    [1,4]
])
df2.columns=['A','B']
df2
# Out:
#     A  B
# 0  12  5
# 1   1  4

# %%
df3=pd.DataFrame(
    [[12,5],
    [1,4]]
)
df3.columns=['B','C']
df3
# Out:
#     B  C
# 0  12  5
# 1   1  4

# %%
pd.concat([df1,df2])
# Out:
#     A  B
# 0   1  5
# 1   5  2
# 0  12  5
# 1   1  4

# %%
pd.concat([df1,df3])
# Out:
#      A   B    C
# 0  1.0   5  NaN
# 1  5.0   2  NaN
# 0  NaN  12  5.0
# 1  NaN   1  4.0

# %%
# Joining with Various Column Names (horizonal)
# df1.join(df2,lsuffix="_one",rsuffix="_two")

# %%
df1.join(df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df1.join(df2)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:12818, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   12814                     suffixes=(lsuffix, rsuffix),
#   12815                     sort=sort,
#   12816                     validate=validate,
#   12817                 )
# > 12818             return merge(
#   12819                 self,
#   12820                 other,
#   12821                 left_on=on,
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\reshape\merge.py:399, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     384 else:
#     385     op = _MergeOperation(
#     386         left_df,
# ...

# %%
df1.join(df2,lsuffix="_one",rsuffix="_two")
# Out:
#    A_one  B_one  A_two  B_two
# 0      1      5     12      5
# 1      5      2      1      4
