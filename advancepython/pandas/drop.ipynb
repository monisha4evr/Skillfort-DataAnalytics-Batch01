# %%
import pandas as pd

# %%
df=pd.read_csv('../../../car_data_500.csv').head()
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin
# 0     76    Japan
# 1     73       US
# 2     80    India
# 3     77  Germany
# 4     74       US

# %%
df.drop([1,2,3],axis=0)
# Out:
#     car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  Model  \
# 0  Ford  20.7       6.0          1823         247    3374        15.5     76
# 4  Tata  18.0       6.0          2968         140    2706         7.2     74
#
#   origin
# 0  Japan
# 4     US

# %%
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin
# 0     76    Japan
# 1     73       US
# 2     80    India
# 3     77  Germany
# 4     74       US

# %%
df.drop([1,2],axis=0,inplace=True)

# %%
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin
# 0     76    Japan
# 3     77  Germany
# 4     74       US

# %%
df.drop(['Model','origin'],axis=1)
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2

# %%
df.drop(columns=['MPO'])
# Out:
#        car  Cylinder  Displacement  Horsepower  weight  Accelarate  Model  \
# 0     Ford       6.0          1823         247    3374        15.5     76
# 3  Hyundai       6.0          4498         196    3317         9.9     77
# 4     Tata       6.0          2968         140    2706         7.2     74
#
#     origin
# 0    Japan
# 3  Germany
# 4       US

# %%
# pop

# %%
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin
# 0     76    Japan
# 3     77  Germany
# 4     74       US

# %%
df
# Out:
#     MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  Model  \
# 0  20.7       6.0          1823         247    3374        15.5     76
# 3  11.5       6.0          4498         196    3317         9.9     77
# 4  18.0       6.0          2968         140    2706         7.2     74
#
#     origin
# 0    Japan
# 3  Germany
# 4       US

# %%
Cylinder=df.pop('Cylinder')

# %%
Cylinder
# Out:
# 0    6.0
# 3    6.0
# 4    6.0
# Name: Cylinder, dtype: float64

# %%
df
# Out:
#     MPO  Displacement  Horsepower  weight  Accelarate  Model   origin
# 0  20.7          1823         247    3374        15.5     76    Japan
# 3  11.5          4498         196    3317         9.9     77  Germany
# 4  18.0          2968         140    2706         7.2     74       US

# %%
df.truncate(0,3,axis=0)
# Out:
#     MPO  Displacement  Horsepower  weight  Accelarate  Model   origin
# 0  20.7          1823         247    3374        15.5     76    Japan
# 3  11.5          4498         196    3317         9.9     77  Germany

# %%
df
# Out:
#     MPO  Displacement  Horsepower  weight  Accelarate  Model   origin
# 0  20.7          1823         247    3374        15.5     76    Japan
# 3  11.5          4498         196    3317         9.9     77  Germany
# 4  18.0          2968         140    2706         7.2     74       US

# %%
df.truncate("MPO","Displacement",axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.truncate("MPO","Displacement",axis=1)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:10824, in NDFrame.truncate(self, before, after, axis, copy)
#   10820
#   10821         # GH 17935
#   10822         # Check that index is sorted
#   10823         if not ax.is_monotonic_increasing and not ax.is_monotonic_decreasing:
# > 10824             raise ValueError("truncate requires a sorted index")
#   10825
#   10826         # if we have a date index, convert to dates, otherwise
#   10827         # treat like a slice
#
# ValueError: truncate requires a sorted index

# %%
df=df.sort_index(axis=1)

# %%
df
# Out:
#    Accelarate  Displacement  Horsepower   MPO  Model   origin  weight
# 0        15.5          1823         247  20.7     76    Japan    3374
# 3         9.9          4498         196  11.5     77  Germany    3317
# 4         7.2          2968         140  18.0     74       US    2706

# %%
df.truncate("MPO","Displacement",axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df.truncate("MPO","Displacement",axis=1)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:10839, in NDFrame.truncate(self, before, after, axis, copy)
#   10835                 # Avoid converting to NaT
#   10836                 after = to_datetime(after)
#   10837
#   10838         if before is not None and after is not None and before > after:
# > 10839             raise ValueError(f"Truncate: {after} must be after {before}")
#   10840
#   10841         if len(ax) > 1 and ax.is_monotonic_decreasing and ax.nunique() > 1:
#   10842             before, after = after, before
#
# ValueError: Truncate: Displacement must be after MPO

# %%
df.truncate("MPO","Model",axis=1)
# Out:
#     MPO  Model
# 0  20.7     76
# 3  11.5     77
# 4  18.0     74
