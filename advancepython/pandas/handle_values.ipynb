# %%
import pandas as pd

# %%
df=pd.read_csv("../../../car_data_500.csv").head(10)

# %%
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
# 5      Kia  15.7       6.0          2659         155    3156        10.2
# 6   Toyota  16.9       8.0          3148         102    3974        15.5
# 7     Ford  19.1       8.0          4693         150    1800        12.7
# 8      BMW  17.5       6.0          3801         221    1818        10.8
# 9     Tata  18.1       6.0          3268         130    2383        11.1
#
#    Model       origin
# 0     76        Japan
# 1     73           US
# 2     80        India
# 3     77      Germany
# 4     74           US
# 5     76           US
# ...

# %% [markdown]
# # get Value Based on index and Column

# %%
df.at[3,'origin']
# Out:
# 'Germany'

# %%
df.at[3,'car']
# Out:
# 'Hyundai'

# %%
df.at[7,'Displacement']
# Out:
# np.int64(4693)

# %%
df.iat[2,4]
# Out:
# np.int64(265)

# %%
df.iat[2,4]=555

# %%
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         555    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
# 5      Kia  15.7       6.0          2659         155    3156        10.2
# 6   Toyota  16.9       8.0          3148         102    3974        15.5
# 7     Ford  19.1       8.0          4693         150    1800        12.7
# 8      BMW  17.5       6.0          3801         221    1818        10.8
# 9     Tata  18.1       6.0          3268         130    2383        11.1
#
#    Model       origin
# 0     76        Japan
# 1     73           US
# 2     80        India
# 3     77      Germany
# 4     74           US
# 5     76           US
# ...

# %%
df.loc[6,'car']
# Out:
# 'Toyota'

# %%
df.iloc[6,0]
# Out:
# 'Toyota'

# %%
df.loc[6].at['car']
# Out:
# 'Toyota'

# %% [markdown]
# # Rows

# %%
df.loc[3]
# Out:
# car             Hyundai
# MPO                11.5
# Cylinder            6.0
# Displacement       4498
# Horsepower          196
# weight             3317
# Accelarate          9.9
# Model                77
# origin          Germany
# Name: 3, dtype: object

# %%
df.loc[3]=["hyndaaaaaai",12,7.0,5544,200,3317,8.5,55,'germany']

# %%
df
# Out:
#            car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0         Ford  20.7       6.0          1823         247    3374        15.5
# 1       Jaguar  17.4       4.0          1793         186    2196        15.9
# 2         Audi  21.3       8.0          1943         555    3527         8.3
# 3  hyndaaaaaai  12.0       7.0          5544         200    3317         8.5
# 4         Tata  18.0       6.0          2968         140    2706         7.2
# 5          Kia  15.7       6.0          2659         155    3156        10.2
# 6       Toyota  16.9       8.0          3148         102    3974        15.5
# 7         Ford  19.1       8.0          4693         150    1800        12.7
# 8          BMW  17.5       6.0          3801         221    1818        10.8
# 9         Tata  18.1       6.0          3268         130    2383        11.1
#
#    Model       origin
# 0     76        Japan
# 1     73           US
# 2     80        India
# 3     55      germany
# ...

# %%
df.loc[3:6]
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
# 5      Kia  15.7       6.0          2659         155    3156        10.2
# 6   Toyota  16.9       8.0          3148         102    3974        15.5
#
#    Model       origin
# 3     77      Germany
# 4     74           US
# 5     76           US
# 6     79  South Korea

# %%
df.loc[[1,3,5,7,9]]
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 5      Kia  15.7       6.0          2659         155    3156        10.2
# 7     Ford  19.1       8.0          4693         150    1800        12.7
# 9     Tata  18.1       6.0          3268         130    2383        11.1
#
#    Model       origin
# 1     73           US
# 3     77      Germany
# 5     76           US
# 7     72  South Korea
# 9     80        India

# %% [markdown]
# # Columns

# %%
df.loc[:,'car']
# Out:
# 0           Ford
# 1         Jaguar
# 2           Audi
# 3    hyndaaaaaai
# 4           Tata
# 5            Kia
# 6         Toyota
# 7           Ford
# 8            BMW
# 9           Tata
# Name: car, dtype: str

# %%
df.loc[:,'Displacement']
# Out:
# 0    1823
# 1    1793
# 2    1943
# 3    5544
# 4    2968
# 5    2659
# 6    3148
# 7    4693
# 8    3801
# 9    3268
# Name: Displacement, dtype: int64

# %%
df.loc[:,'car':'Displacement']
# Out:
#            car   MPO  Cylinder  Displacement
# 0         Ford  20.7       6.0          1823
# 1       Jaguar  17.4       4.0          1793
# 2         Audi  21.3       8.0          1943
# 3  hyndaaaaaai  12.0       7.0          5544
# 4         Tata  18.0       6.0          2968
# 5          Kia  15.7       6.0          2659
# 6       Toyota  16.9       8.0          3148
# 7         Ford  19.1       8.0          4693
# 8          BMW  17.5       6.0          3801
# 9         Tata  18.1       6.0          3268

# %%
df.loc[:,['car','Displacement']]
# Out:
#            car  Displacement
# 0         Ford          1823
# 1       Jaguar          1793
# 2         Audi          1943
# 3  hyndaaaaaai          5544
# 4         Tata          2968
# 5          Kia          2659
# 6       Toyota          3148
# 7         Ford          4693
# 8          BMW          3801
# 9         Tata          3268

# %%
df.loc[1:3,['car','Displacement']]
# Out:
#            car  Displacement
# 1       Jaguar          1793
# 2         Audi          1943
# 3  hyndaaaaaai          5544

# %%
df
# Out:
#            car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0         Ford  20.7       6.0          1823         247    3374        15.5
# 1       Jaguar  17.4       4.0          1793         186    2196        15.9
# 2         Audi  21.3       8.0          1943         555    3527         8.3
# 3  hyndaaaaaai  12.0       7.0          5544         200    3317         8.5
# 4         Tata  18.0       6.0          2968         140    2706         7.2
# 5          Kia  15.7       6.0          2659         155    3156        10.2
# 6       Toyota  16.9       8.0          3148         102    3974        15.5
# 7         Ford  19.1       8.0          4693         150    1800        12.7
# 8          BMW  17.5       6.0          3801         221    1818        10.8
# 9         Tata  18.1       6.0          3268         130    2383        11.1
#
#    Model       origin
# 0     76        Japan
# 1     73           US
# 2     80        India
# 3     55      germany
# ...

# %%
df.add_prefix("item_",axis=1)
# Out:
#       item_car  item_MPO  item_Cylinder  item_Displacement  item_Horsepower  \
# 0         Ford      20.7            6.0               1823              247
# 1       Jaguar      17.4            4.0               1793              186
# 2         Audi      21.3            8.0               1943              555
# 3  hyndaaaaaai      12.0            7.0               5544              200
# 4         Tata      18.0            6.0               2968              140
# 5          Kia      15.7            6.0               2659              155
# 6       Toyota      16.9            8.0               3148              102
# 7         Ford      19.1            8.0               4693              150
# 8          BMW      17.5            6.0               3801              221
# 9         Tata      18.1            6.0               3268              130
#
#    item_weight  item_Accelarate  item_Model  item_origin
# 0         3374             15.5          76        Japan
# ...

# %%
df.add_prefix("item_",axis=0)
# Out:
#                 car   MPO  Cylinder  Displacement  Horsepower  weight  \
# item_0         Ford  20.7       6.0          1823         247    3374
# item_1       Jaguar  17.4       4.0          1793         186    2196
# item_2         Audi  21.3       8.0          1943         555    3527
# item_3  hyndaaaaaai  12.0       7.0          5544         200    3317
# item_4         Tata  18.0       6.0          2968         140    2706
# item_5          Kia  15.7       6.0          2659         155    3156
# item_6       Toyota  16.9       8.0          3148         102    3974
# item_7         Ford  19.1       8.0          4693         150    1800
# item_8          BMW  17.5       6.0          3801         221    1818
# item_9         Tata  18.1       6.0          3268         130    2383
#
#         Accelarate  Model       origin
# item_0        15.5     76        Japan
# item_1        15.9     73           US
# item_2         8.3     80        India
# ...

# %%
df.add_suffix("_item",axis=0)
# Out:
#                 car   MPO  Cylinder  Displacement  Horsepower  weight  \
# 0_item         Ford  20.7       6.0          1823         247    3374
# 1_item       Jaguar  17.4       4.0          1793         186    2196
# 2_item         Audi  21.3       8.0          1943         555    3527
# 3_item  hyndaaaaaai  12.0       7.0          5544         200    3317
# 4_item         Tata  18.0       6.0          2968         140    2706
# 5_item          Kia  15.7       6.0          2659         155    3156
# 6_item       Toyota  16.9       8.0          3148         102    3974
# 7_item         Ford  19.1       8.0          4693         150    1800
# 8_item          BMW  17.5       6.0          3801         221    1818
# 9_item         Tata  18.1       6.0          3268         130    2383
#
#         Accelarate  Model       origin
# 0_item        15.5     76        Japan
# 1_item        15.9     73           US
# 2_item         8.3     80        India
# ...

# %%
df
# Out:
#            car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0         Ford  20.7       6.0          1823         247    3374        15.5
# 1       Jaguar  17.4       4.0          1793         186    2196        15.9
# 2         Audi  21.3       8.0          1943         555    3527         8.3
# 3  hyndaaaaaai  12.0       7.0          5544         200    3317         8.5
# 4         Tata  18.0       6.0          2968         140    2706         7.2
# 5          Kia  15.7       6.0          2659         155    3156        10.2
# 6       Toyota  16.9       8.0          3148         102    3974        15.5
# 7         Ford  19.1       8.0          4693         150    1800        12.7
# 8          BMW  17.5       6.0          3801         221    1818        10.8
# 9         Tata  18.1       6.0          3268         130    2383        11.1
#
#    Model       origin
# 0     76        Japan
# 1     73           US
# 2     80        India
# 3     55      germany
# ...

# %%
df['Cylinder'].idxmax()
# Out:
# 2

# %%
df['Cylinder'].idxmin()
# Out:
# 1

# %%
df['Cylinder'].argmax()
# Out:
# np.int64(2)

# %%
df['Cylinder'].argmin()
# Out:
# np.int64(1)

# %%
df['Cylinder'].max()
# Out:
# np.float64(8.0)

# %%
df['Cylinder'].min()
# Out:
# np.float64(4.0)
