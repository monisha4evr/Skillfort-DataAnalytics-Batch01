# %%
import numpy as np

# %%
a=np.array([["m1","m2"],["30","40"]])
print(a)
print(a.ndim)
ar=np.savetxt("test.csv",a,delimiter=",",fmt="%s")
# Out:
# [['m1' 'm2']
#  ['30' '40']]
# 2

# %%
a=np.genfromtxt("test.csv",delimiter=",")
print(a)
# Out:
# [[nan nan]
#  [30. 40.]]
