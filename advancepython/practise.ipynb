# %%
import numpy as np

# %%
a=np.array([["m1","m2"],["m3","m4"],['1','2'],['2','3']])
print(a.ndim)
np.savetxt("sample.csv",a,delimiter=',',fmt="%s")
a = np.delete(a, 0, axis=0)
np.savetxt("sample.csv",a,delimiter=',',fmt="%s")
total=a[1:,0 ]+ a[2:,1]
print(total)
# Out:
# 2
# ['13' '23']
