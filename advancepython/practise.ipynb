# %%
import numpy as np

# %%
a=np.array([["m1","m2"],['1','2'],['2','3'],['2','3']])
print(a.ndim)
np.savetxt("sample.csv",a,delimiter=',',fmt="%s")
#a = np.delete(a, 0, axis=0)
#np.savetxt("sample.csv",a,delimiter=',',fmt="%s")
# Out:
# 2

# %%
a=[1,2,3,4]
b=[5,6,7,8]
print(a)
np.stack((a,b)) # default axis=0
# Out:
# [1, 2, 3, 4]
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
np.stack((a,b),axis=0)
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
np.stack((a,b),axis=1)
# Out:
# array([[1, 5],
#        [2, 6],
#        [3, 7],
#        [4, 8]])

# %%
np.hstack((a,b))
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
np.vstack((a,b))
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
np.concatenate((a,b))
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])
