# %%
import numpy as np
b=np.array([1,2,3],[4,6,7])
print(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import numpy as np
# ----> 2 b=np.array([1,2,3],[4,6,7])
#       3 print(b)
#
# TypeError: Field elements must be 2- or 3-tuples, got '4'
