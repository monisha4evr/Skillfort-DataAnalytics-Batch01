# %% [markdown]
# # Basic

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
a="Dhruv"
b="Magi"
print(a+b)
# Out:
# DhruvMagi

# %%
a=10
b="Dhruv"
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 a=10
#       2 b="Dhruv"
# ----> 3 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
